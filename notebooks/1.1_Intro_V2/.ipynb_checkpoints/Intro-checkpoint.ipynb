# %% [markdown]
# # Computer Vision Fundamentals: OpenCV with Python
#
# OpenCV (Open Source Computer Vision) is a library of programming functions mainly aimed at real-time computer vision. OpenCV is written in C++, but there are bindings in Python, Java and Matlab. So, here we will perform some basic digital image processing operations using OpenCV as a Python module.

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dealing with images...

# %%
I = cv.imread("kaiju.jpg",1)

plt.imshow(I[...,::-1])
plt.show()

# %%
print(I[0,0])

I[54,469]
# Out:
# [22 15  6]
# array([72, 62, 44], dtype=uint8)

# %%
for i in range(150,251):
    for j in range(400,501):
        I[i,j] = (255,0,255) # magenta (B=255, G=0, R=255)

plt.imshow(I[...,::-1])
plt.xticks([]), plt.yticks([])
plt.show()

# %%
cv.line(I,(0,0),(100,200),(255,0,0),5) # blue (B=255, G=0, R=0)
cv.line(I,(100,200),(200,50),(0,255,0),5) # green (B=0, G=255, R=0)
cv.line(I,(200,50),(300,150),(0,0,255),5) # red (B=0, G=0, R=255)

plt.imshow(I[...,::-1])
plt.xticks([]), plt.yticks([])
plt.show()

# %%
cv.imwrite("test.png", I)
# Out:
# True

# %% [markdown]
# ## Dealing with videos...
#
# Now, read the next video and store its frames:
#
# <img src="video.gif">

# %%
V = cv.VideoCapture("video.avi")
ret,f = V.read()
plt.imshow(f[...,::-1])

print(V.get(cv.CAP_PROP_FRAME_COUNT))

print(V.get(cv.CAP_PROP_POS_FRAMES))
# Out:
# 490.0
# 1.0

# %%
# bash command
# !mkdir frames 

V.set(cv.CAP_PROP_POS_FRAMES, 0); 
ret,f = V.read()
counter = 0
while ret:
    counter += 1
    fname = "frames/frame"+str(counter)+".jpg"
    cv.imwrite(fname, f)
    print("Generating frame "+str(counter))
    ret,f = V.read()
# Out:
# A subdirectory or file frames already exists.
# Generating frame 1
# Generating frame 2
# Generating frame 3
# Generating frame 4
# Generating frame 5
# Generating frame 6
# Generating frame 7
# Generating frame 8
# Generating frame 9
# Generating frame 10
# Generating frame 11
# Generating frame 12
# Generating frame 13
# Generating frame 14
# Generating frame 15
# Generating frame 16
# Generating frame 17
# Generating frame 18
# Generating frame 19
# Generating frame 20
# Generating frame 21
# Generating frame 22
# Generating frame 23
# Generating frame 24
# Generating frame 25
# Generating frame 26
# Generating frame 27
# Generating frame 28
# Generating frame 29
# Generating frame 30
# Generating frame 31
# Generating frame 32
# Generating frame 33
# Generating frame 34
# Generating frame 35
# Generating frame 36
# Generating frame 37
# Generating frame 38
# Generating frame 39
# Generating frame 40
# Generating frame 41
# Generating frame 42
# Generating frame 43
# Generating frame 44
# Generating frame 45
# Generating frame 46
# Generating frame 47
# Generating frame 48
# Generating frame 49
# Generating frame 50
# Generating frame 51
# Generating frame 52
# Generating frame 53
# Generating frame 54
# Generating frame 55
# Generating frame 56
# Generating frame 57
# Generating frame 58
# Generating frame 59
# Generating frame 60
# Generating frame 61
# Generating frame 62
# Generating frame 63
# Generating frame 64
# Generating frame 65
# Generating frame 66
# Generating frame 67
# Generating frame 68
# Generating frame 69
# Generating frame 70
# Generating frame 71
# Generating frame 72
# Generating frame 73
# Generating frame 74
# Generating frame 75
# Generating frame 76
# Generating frame 77
# Generating frame 78
# Generating frame 79
# Generating frame 80
# Generating frame 81
# Generating frame 82
# Generating frame 83
# Generating frame 84
# Generating frame 85
# Generating frame 86
# Generating frame 87
# Generating frame 88
# Generating frame 89
# Generating frame 90
# Generating frame 91
# Generating frame 92
# Generating frame 93
# Generating frame 94
# Generating frame 95
# Generating frame 96
# Generating frame 97
# Generating frame 98
# Generating frame 99
# Generating frame 100
# Generating frame 101
# Generating frame 102
# Generating frame 103
# Generating frame 104
# Generating frame 105
# Generating frame 106
# Generating frame 107
# Generating frame 108
# Generating frame 109
# Generating frame 110
# Generating frame 111
# Generating frame 112
# Generating frame 113
# Generating frame 114
# Generating frame 115
# Generating frame 116
# Generating frame 117
# Generating frame 118
# Generating frame 119
# Generating frame 120
# Generating frame 121
# Generating frame 122
# Generating frame 123
# Generating frame 124
# Generating frame 125
# Generating frame 126
# Generating frame 127
# Generating frame 128
# Generating frame 129
# Generating frame 130
# Generating frame 131
# Generating frame 132
# Generating frame 133
# Generating frame 134
# Generating frame 135
# Generating frame 136
# Generating frame 137
# Generating frame 138
# Generating frame 139
# Generating frame 140
# Generating frame 141
# Generating frame 142
# Generating frame 143
# Generating frame 144
# Generating frame 145
# Generating frame 146
# Generating frame 147
# Generating frame 148
# Generating frame 149
# Generating frame 150
# Generating frame 151
# Generating frame 152
# Generating frame 153
# Generating frame 154
# Generating frame 155
# Generating frame 156
# Generating frame 157
# Generating frame 158
# Generating frame 159
# Generating frame 160
# Generating frame 161
# Generating frame 162
# Generating frame 163
# Generating frame 164
# Generating frame 165
# Generating frame 166
# Generating frame 167
# Generating frame 168
# Generating frame 169
# Generating frame 170
# Generating frame 171
# Generating frame 172
# Generating frame 173
# Generating frame 174
# Generating frame 175
# Generating frame 176
# Generating frame 177
# Generating frame 178
# Generating frame 179
# Generating frame 180
# Generating frame 181
# Generating frame 182
# Generating frame 183
# Generating frame 184
# Generating frame 185
# Generating frame 186
# Generating frame 187
# Generating frame 188
# Generating frame 189
# Generating frame 190
# Generating frame 191
# Generating frame 192
# Generating frame 193
# Generating frame 194
# Generating frame 195
# Generating frame 196
# Generating frame 197
# Generating frame 198
# Generating frame 199
# Generating frame 200
# Generating frame 201
# Generating frame 202
# Generating frame 203
# Generating frame 204
# Generating frame 205
# Generating frame 206
# Generating frame 207
# Generating frame 208
# Generating frame 209
# Generating frame 210
# Generating frame 211
# Generating frame 212
# Generating frame 213
# Generating frame 214
# Generating frame 215
# Generating frame 216
# Generating frame 217
# Generating frame 218
# Generating frame 219
# Generating frame 220
# Generating frame 221
# Generating frame 222
# Generating frame 223
# Generating frame 224
# Generating frame 225
# Generating frame 226
# Generating frame 227
# Generating frame 228
# Generating frame 229
# Generating frame 230
# Generating frame 231
# Generating frame 232
# Generating frame 233
# Generating frame 234
# Generating frame 235
# Generating frame 236
# Generating frame 237
# Generating frame 238
# Generating frame 239
# Generating frame 240
# Generating frame 241
# Generating frame 242
# Generating frame 243
# Generating frame 244
# Generating frame 245
# Generating frame 246
# Generating frame 247
# Generating frame 248
# Generating frame 249
# Generating frame 250
# Generating frame 251
# Generating frame 252
# Generating frame 253
# Generating frame 254
# Generating frame 255
# Generating frame 256
# Generating frame 257
# Generating frame 258
# Generating frame 259
# Generating frame 260
# Generating frame 261
# Generating frame 262
# Generating frame 263
# Generating frame 264
# Generating frame 265
# Generating frame 266
# Generating frame 267
# Generating frame 268
# Generating frame 269
# Generating frame 270
# Generating frame 271
# Generating frame 272
# Generating frame 273
# Generating frame 274
# Generating frame 275
# Generating frame 276
# Generating frame 277
# Generating frame 278
# Generating frame 279
# Generating frame 280
# Generating frame 281
# Generating frame 282
# Generating frame 283
# Generating frame 284
# Generating frame 285
# Generating frame 286
# Generating frame 287
# Generating frame 288
# Generating frame 289
# Generating frame 290
# Generating frame 291
# Generating frame 292
# Generating frame 293
# Generating frame 294
# Generating frame 295
# Generating frame 296
# Generating frame 297
# Generating frame 298
# Generating frame 299
# Generating frame 300
# Generating frame 301
# Generating frame 302
# Generating frame 303
# Generating frame 304
# Generating frame 305
# Generating frame 306
# Generating frame 307
# Generating frame 308
# Generating frame 309
# Generating frame 310
# Generating frame 311
# Generating frame 312
# Generating frame 313
# Generating frame 314
# Generating frame 315
# Generating frame 316
# Generating frame 317
# Generating frame 318
# Generating frame 319
# Generating frame 320
# Generating frame 321
# Generating frame 322
# Generating frame 323
# Generating frame 324
# Generating frame 325
# Generating frame 326
# Generating frame 327
# Generating frame 328
# Generating frame 329
# Generating frame 330
# Generating frame 331
# Generating frame 332
# Generating frame 333
# Generating frame 334
# Generating frame 335
# Generating frame 336
# Generating frame 337
# Generating frame 338
# Generating frame 339
# Generating frame 340
# Generating frame 341
# Generating frame 342
# Generating frame 343
# Generating frame 344
# Generating frame 345
# Generating frame 346
# Generating frame 347
# Generating frame 348
# Generating frame 349
# Generating frame 350
# Generating frame 351
# Generating frame 352
# Generating frame 353
# Generating frame 354
# Generating frame 355
# Generating frame 356
# Generating frame 357
# Generating frame 358
# Generating frame 359
# Generating frame 360
# Generating frame 361
# Generating frame 362
# Generating frame 363
# Generating frame 364
# Generating frame 365
# Generating frame 366
# Generating frame 367
# Generating frame 368
# Generating frame 369
# Generating frame 370
# Generating frame 371
# Generating frame 372
# Generating frame 373
# Generating frame 374
# Generating frame 375
# Generating frame 376
# Generating frame 377
# Generating frame 378
# Generating frame 379
# Generating frame 380
# Generating frame 381
# Generating frame 382
# Generating frame 383
# Generating frame 384
# Generating frame 385
# Generating frame 386
# Generating frame 387
# Generating frame 388
# Generating frame 389
# Generating frame 390
# Generating frame 391
# Generating frame 392
# Generating frame 393
# Generating frame 394
# Generating frame 395
# Generating frame 396
# Generating frame 397
# Generating frame 398
# Generating frame 399
# Generating frame 400
# Generating frame 401
# Generating frame 402
# Generating frame 403
# Generating frame 404
# Generating frame 405
# Generating frame 406
# Generating frame 407
# Generating frame 408
# Generating frame 409
# Generating frame 410
# Generating frame 411
# Generating frame 412
# Generating frame 413
# Generating frame 414
# Generating frame 415
# Generating frame 416
# Generating frame 417
# Generating frame 418
# Generating frame 419
# Generating frame 420
# Generating frame 421
# Generating frame 422
# Generating frame 423
# Generating frame 424
# Generating frame 425
# Generating frame 426
# Generating frame 427
# Generating frame 428
# Generating frame 429
# Generating frame 430
# Generating frame 431
# Generating frame 432
# Generating frame 433
# Generating frame 434
# Generating frame 435
# Generating frame 436
# Generating frame 437
# Generating frame 438
# Generating frame 439
# Generating frame 440
# Generating frame 441
# Generating frame 442
# Generating frame 443
# Generating frame 444
# Generating frame 445
# Generating frame 446
# Generating frame 447
# Generating frame 448
# Generating frame 449
# Generating frame 450
# Generating frame 451
# Generating frame 452
# Generating frame 453
# Generating frame 454
# Generating frame 455
# Generating frame 456
# Generating frame 457
# Generating frame 458
# Generating frame 459
# Generating frame 460
# Generating frame 461
# Generating frame 462
# Generating frame 463
# Generating frame 464
# Generating frame 465
# Generating frame 466
# Generating frame 467
# Generating frame 468
# Generating frame 469
# Generating frame 470
# Generating frame 471
# Generating frame 472
# Generating frame 473
# Generating frame 474
# Generating frame 475
# Generating frame 476
# Generating frame 477
# Generating frame 478
# Generating frame 479
# Generating frame 480
# Generating frame 481
# Generating frame 482
# Generating frame 483
# Generating frame 484
# Generating frame 485
# Generating frame 486
# Generating frame 487
# Generating frame 488
# Generating frame 489
# Generating frame 490

# %% [markdown]
# Inside the frame folder you will find the generated video frames:
#
# <img src="frames.png">

# %% [markdown]
# ### Arithmetic Operations on Images
#
# We can perform arithmetic operations over images. See how to average the frames of this video:
#
# <img src="street.gif">

# %%
V = cv.VideoCapture("street.avi")

H = V.get(cv.CAP_PROP_FRAME_HEIGHT)
W = V.get(cv.CAP_PROP_FRAME_WIDTH)
frameSum = np.zeros(shape=(int(H),int(W),3))

ret,f = V.read()
while ret:
    frameSum += f
    ret,f = V.read()

Nf = V.get(cv.CAP_PROP_FRAME_COUNT)
frameAvg = frameSum/Nf
frameAvg = frameAvg.astype(np.uint8)

plt.imshow(frameAvg[...,::-1]);

# %% [markdown]
# Then, implement a simple substraction between the average frame and some frame with a car passing by:

# %%
V.set(cv.CAP_PROP_POS_FRAMES, 39);
ret,f = V.read()
plt.imshow((frameAvg - f)[...,::-1]);

# %%
I1 = cv.imread('kaiju.jpg')
I2 = cv.imread('optimus.jpg')

alpha = 0.6
blending = cv.addWeighted(I1,alpha,I2,1-alpha,0)

plt.figure(figsize=(15,20))
plt.subplot(131)
plt.imshow(I1[...,::-1]); 
plt.xticks([]), plt.yticks([]);
plt.subplot(132)
plt.imshow(I2[...,::-1]);
plt.xticks([]), plt.yticks([]);
plt.subplot(133)
plt.imshow(blending[...,::-1]);
plt.xticks([]), plt.yticks([]);
